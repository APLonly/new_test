# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("archive.zip")

# %%
df.head(5)
# Out:
#    index  Year-Month  Agency Number                Agency Name  \
# 0      0      201307           1000  OKLAHOMA STATE UNIVERSITY
# 1      1      201307           1000  OKLAHOMA STATE UNIVERSITY
# 2      2      201307           1000  OKLAHOMA STATE UNIVERSITY
# 3      3      201307           1000  OKLAHOMA STATE UNIVERSITY
# 4      4      201307           1000  OKLAHOMA STATE UNIVERSITY
#
#   Cardholder Last Name Cardholder First Initial                   Description  \
# 0                Mason                        C              GENERAL PURCHASE
# 1                Mason                        C                  ROOM CHARGES
# 2               Massey                        J              GENERAL PURCHASE
# 3               Massey                        T              GENERAL PURCHASE
# 4        Mauro-Herrera                        M  HAMMERMILL COPY PLUS COPY EA
#
#    Amount          Vendor        Transaction Date             Posted Date  \
# 0  890.00           NACAS  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 1  368.96  SHERATON HOTEL  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 2  165.82  SEARS.COM 9300  07/29/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 3   96.39  WAL-MART #0137  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 4  125.96  STAPLES DIRECT  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
#
#                         Merchant Category Code (MCC)
# 0        CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS
# 1                                           SHERATON
# 2  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 3                    GROCERY STORES,AND SUPERMARKETS
# 4  STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...

# %%
df.columns
# Out:
# Index(['index', 'Year-Month', 'Agency Number', 'Agency Name',
#        'Cardholder Last Name', 'Cardholder First Initial', 'Description',
#        'Amount', 'Vendor', 'Transaction Date', 'Posted Date',
#        'Merchant Category Code (MCC)'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#          index  Year-Month  Agency Number                Agency Name  \
# 13597    13597      201308           1000  OKLAHOMA STATE UNIVERSITY
# 69663    69663      201308           4000  DEPARTMENT OF AGRICULTURE
# 343254  343254      201404          76000     UNIVERSITY OF OKLAHOMA
# 372657  372657      201405           1000  OKLAHOMA STATE UNIVERSITY
# 229        229      201307           1000  OKLAHOMA STATE UNIVERSITY
#
#        Cardholder Last Name Cardholder First Initial       Description  \
# 13597               Colosky                        D  GENERAL PURCHASE
# 69663                Keener                        K        AIR TRAVEL
# 343254             CHAMBERS                        T  GENERAL PURCHASE
# 372657               Adkins                        A  GENERAL PURCHASE
# 229                   Hines                        G  GENERAL PURCHASE
#
#          Amount                     Vendor        Transaction Date  \
# 13597    115.47      KINNUNEN SALES & RENT  08/13/2013 12:00:00 AM
# 69663    333.60  AMERICAN AI 0017297591254  08/06/2013 12:00:00 AM
# 343254  1500.00             WAL-MART #0212  04/07/2014 12:00:00 AM
# 372657   175.00   ASSN OF AMER GEOGRAPHERS  04/30/2014 12:00:00 AM
# 229      309.69      STILLWATER WINLECTRIC  07/26/2013 12:00:00 AM
#
#                    Posted Date                    Merchant Category Code (MCC)
# 13597   08/14/2013 12:00:00 AM  COMMERCIAL EQUIPMENT, NOT ELSEWHERE CLASSIFIED
# 69663   08/08/2013 12:00:00 AM                               AMERICAN AIRLINES
# 343254  04/08/2014 12:00:00 AM                 GROCERY STORES,AND SUPERMARKETS
# 372657  05/01/2014 12:00:00 AM     CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS
# 229     07/29/2013 12:00:00 AM     PLUMBING AND HEATING EQUIPMENT AND SUPPLIES

# %%
df_new = df.drop('index', axis=1)
for column in df_new.columns:
    count=0
    for value in df[column].unique():
        count += 1
    print(f"{column} has unique value: {count}")
    print('-'*20)
# Out:
# Year-Month has unique value: 12
# --------------------
# Agency Number has unique value: 116
# --------------------
# Agency Name has unique value: 124
# --------------------
# Cardholder Last Name has unique value: 3911
# --------------------
# Cardholder First Initial has unique value: 38
# --------------------
# Description has unique value: 88749
# --------------------
# Amount has unique value: 90447
# --------------------
# Vendor has unique value: 86729
# --------------------
# Transaction Date has unique value: 392
# --------------------
# Posted Date has unique value: 258
# --------------------
# Merchant Category Code (MCC) has unique value: 435
# --------------------

# %%
df[df['Amount'] == df['Amount'].max()]
# Out:
#          index  Year-Month  Agency Number  \
# 218925  218925      201309          77000
#
#                                   Agency Name Cardholder Last Name  \
# 218925  UNIV. OF OKLA. HEALTH SCIENCES CENTER                77000
#
#        Cardholder First Initial       Description      Amount  \
# 218925                        7  GENERAL PURCHASE  1903858.37
#
#                     Vendor        Transaction Date             Posted Date  \
# 218925  PAYMENT ADJUSTMENT  08/21/2013 12:00:00 AM  09/12/2013 12:00:00 AM
#
#        Merchant Category Code (MCC)
# 218925                   OTHER FEES

# %%
df.shape
# Out:
# (442458, 12)

# %%
small_df = df[:1000]

# %%
small_df.shape
# Out:
# (1000, 12)
